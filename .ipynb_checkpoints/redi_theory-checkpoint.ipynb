# %%
# %matplotlib inline
import xmitgcm
import xgcm
import xarray as xr
from xlayers import finegrid, layers
from xlayers.core import layers_apply
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams.update({'font.size': 14})

# %%
#Let's set the basin width to 6000km (and make it constant for now)
La = 6*10**6*np.ones(144)

# %%
# We are going to pretend that the ocean is 4000m deep and look at a layer between some isopycnal and the bottom
#that layer has thickness modelh - again constant for now
modelh=4000-1000*np.ones(144)#

#if you want to play around with changing modelh so it is not constant, start here
#modelh =(4000-1000*(np.tanh((np.arange(0,144)-14)/5)+1)/2-100)

#so the depth of the isopycnal is 4000-modelh
plt.plot(4000-modelh)

# %%
#set up latitude
lat = np.linspace(-70,70,144)

# %%
#Here's the transport in Sv
vatl=(-6*np.ones(144)*10**6-np.arange(0,144)*10**5)*(np.tanh((np.arange(0,144)-20)/5)+1)/2

plt.plot(lat,vatl/10**6,'k--')

# %%
#modern
import redi_analytical as ra

# we're going to run this model for a 540000 timesteps
ntime=540000

#boundries
Csouth=5
Cnorth=30

#stuff to use in plotting
T=np.zeros(((25,144,40000)))
modelkappa=np.zeros((25,144))


for i in range(1,25):
    #test isopycnal mixing 
    modelkappa[i,:]=i*200*np.ones(144)
    #The output of this model is Temperature
    T[i,:,:]=ra.redi_simple(lat,modelkappa[i],vatl,La,modelh,ntime,10**-2,Csouth,Cnorth)

# %%
#line plot
fig, ax = plt.subplots(figsize=(10,10))
for i in range(1,25):
    ax.plot(T[i,:,0],lat[:],label='modelkappa = '+str(i*250))
plt.legend()
plt.xlabel("Temperature")
plt.ylabel("Latitude")
plt.title("isopycnal mixing effect on temperture in a channel")
plt.tight_layout()
plt.savefig('lineplot_Lat_kappa_temp.png')

# %%
#pcolor plot
plt.pcolor(lat,modelkappa[1:],T[1:,:,0])
plt.colorbar()
plt.xlabel("latitude")
plt.ylabel("ispycnal mixing coefficent")
plt.title("Temperature profile")
plt.savefig("pcolor_temp_lat_kappa")

# %%
# example animation
import numpy as np
from matplotlib import pyplot as plt, animation
plt.rcParams["figure.figsize"] = [6.00, 4.50]
plt.rcParams["figure.autolayout"] = True
fig, ax = plt.subplots()
ax.set(xlim=(5, 30), ylim=(-70, 70))
line, = ax.plot(T[:, 0],lat, color='k', lw=2)
def animate(i):
    line.set_xdata(T[:, i])
anim = animation.FuncAnimation(fig, animate, interval=100, frames=400000 - 1)
#anim.save('name.gif')
plt.show()

# %%
# temperture distribution at the surface
ny=144
Cs=np.zeros(ny)
Cs[:]= 20*(((np.cos(np.pi*lat[:]/140))**2) + (0.1*np.exp(- (lat[:]/120-1)**2)))
plt.plot(Cs)
